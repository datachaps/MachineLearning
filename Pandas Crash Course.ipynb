# %% [markdown]
# # Pandas crash course

# %% [markdown]
# What is pandas? <br>
# Pandas is a python library used for working with datasets. It has functions to analyze, clean and manipulate data.

# %% [markdown]
# ## Import

# %%
import pandas as pd

# %% [markdown]
# ## Load data from various sources

# %% [markdown]
# What is a dataframe?<br>
# A dataframe is a data structure constructed with rows and columns,
# similar to a database or excel spreadsheet.<br>
# It is a 2 dimensional table of rows and columns.

# %% [markdown]
# ### Read from csv file

# %%
df=pd.read_csv("./Datasets/car_price_dataset.csv")
df
df.to_excel("./Datasets/car_price_dataset.xlsx")
# df.to_json("./Datasets/car_price_dataset.json")

# %%
def reload_data():
    return pd.read_csv("./Datasets/car_price_dataset.csv")

# %% [markdown]
# ### Read from json file

# %%
df_json=pd.read_json("./Datasets/car_price_dataset.json")
df_json
# Out:
#            Brand     Model  Year  Engine_Size Fuel_Type    Transmission  \
# 0            Kia       Rio  2020          4.2    Diesel          Manual
# 1      Chevrolet    Malibu  2012          2.0    Hybrid       Automatic
# 2       Mercedes       GLA  2020          4.2    Diesel       Automatic
# 3           Audi        Q5  2023          2.0  Electric          Manual
# 4     Volkswagen      Golf  2003          2.6    Hybrid  Semi-Automatic
# ...          ...       ...   ...          ...       ...             ...
# 9995         Kia    Optima  2004          3.7    Diesel  Semi-Automatic
# 9996   Chevrolet    Impala  2002          1.4  Electric       Automatic
# 9997         BMW  3 Series  2010          3.0    Petrol       Automatic
# 9998        Ford  Explorer  2002          1.4    Hybrid       Automatic
# 9999  Volkswagen    Tiguan  2001          2.1    Diesel          Manual
#
#       Mileage  Doors  Owner_Count  Price
# 0      289944      3            5   8501
# ...

# %% [markdown]
# ### Read from Excel file

# %%
df_excel=pd.read_excel("./Datasets/car_price_dataset.xlsx")
df_excel
# Out:
#       Unnamed: 0       Brand     Model  Year  Engine_Size Fuel_Type  \
# 0              0         Kia       Rio  2020          4.2    Diesel
# 1              1   Chevrolet    Malibu  2012          2.0    Hybrid
# 2              2    Mercedes       GLA  2020          4.2    Diesel
# 3              3        Audi        Q5  2023          2.0  Electric
# 4              4  Volkswagen      Golf  2003          2.6    Hybrid
# ...          ...         ...       ...   ...          ...       ...
# 9995        9995         Kia    Optima  2004          3.7    Diesel
# 9996        9996   Chevrolet    Impala  2002          1.4  Electric
# 9997        9997         BMW  3 Series  2010          3.0    Petrol
# 9998        9998        Ford  Explorer  2002          1.4    Hybrid
# 9999        9999  Volkswagen    Tiguan  2001          2.1    Diesel
#
#         Transmission  Mileage  Doors  Owner_Count  Price
# 0             Manual   289944      3            5   8501
# ...

# %% [markdown]
# ### Create from dictionary

# %%
dict_data = {'column1':[11,21,31,41],'column2':[12,22,32,42]}
df_dict = pd.DataFrame.from_dict(data=dict_data)
df_dict
# Out:
#    column1  column2
# 0       11       12
# 1       21       22
# 2       31       32
# 3       41       42

# %%
df_dict_orient = pd.DataFrame.from_dict(data=dict_data,orient='index')
df_dict_orient
# Out:
#           0   1   2   3
# column1  11  21  31  41
# column2  12  22  32  42

# %%
df_dict_columns = pd.DataFrame.from_dict(data=dict_data,orient='index',columns=['column1','column2','column3','column4'])
df_dict_columns
# Out:
#          column1  column2  column3  column4
# column1       11       21       31       41
# column2       12       22       32       42

# %% [markdown]
# ### Without headers

# %%
df_csv=pd.read_csv("./Datasets/sonar_data.csv",header=None)
df_csv
# Out:
#          0       1       2       3       4       5       6       7       8   \
# 0    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1    0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2    0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3    0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 203  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 204  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 205  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 206  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 207  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
# ...

# %% [markdown]
# ## Visualize data

# %% [markdown]
# ### head(), tail(), iloc() and loc()

# %%
df.head(-30)
# Out:
#            Brand     Model  Year  Engine_Size Fuel_Type    Transmission  \
# 0            Kia       Rio  2020          4.2    Diesel          Manual
# 1      Chevrolet    Malibu  2012          2.0    Hybrid       Automatic
# 2       Mercedes       GLA  2020          4.2    Diesel       Automatic
# 3           Audi        Q5  2023          2.0  Electric          Manual
# 4     Volkswagen      Golf  2003          2.6    Hybrid  Semi-Automatic
# ...          ...       ...   ...          ...       ...             ...
# 9965      Toyota     Camry  2017          5.0  Electric          Manual
# 9966    Mercedes       GLA  2011          1.3    Petrol       Automatic
# 9967         BMW  3 Series  2002          4.5    Petrol       Automatic
# 9968        Audi        A3  2006          2.5    Petrol  Semi-Automatic
# 9969   Chevrolet   Equinox  2016          3.9  Electric       Automatic
#
#       Mileage  Doors  Owner_Count  Price
# 0      289944      3            5   8501
# ...

# %%
df.tail(10)
# Out:
#            Brand     Model  Year  Engine_Size Fuel_Type    Transmission  \
# 9990        Audi        A3  2019          1.8  Electric          Manual
# 9991    Mercedes   E-Class  2017          1.1    Diesel       Automatic
# 9992         BMW  5 Series  2016          1.2    Hybrid       Automatic
# 9993       Honda    Accord  2019          4.7    Hybrid  Semi-Automatic
# 9994       Honda     Civic  2016          2.9    Petrol          Manual
# 9995         Kia    Optima  2004          3.7    Diesel  Semi-Automatic
# 9996   Chevrolet    Impala  2002          1.4  Electric       Automatic
# 9997         BMW  3 Series  2010          3.0    Petrol       Automatic
# 9998        Ford  Explorer  2002          1.4    Hybrid       Automatic
# 9999  Volkswagen    Tiguan  2001          2.1    Diesel          Manual
#
#       Mileage  Doors  Owner_Count  Price
# 9990    85496      4            3  11890
# 9991   179286      5            1   8214
# 9992    13386      3            5  12332
# ...

# %%
df.iloc[3]
# Out:
# Brand               Audi
# Model                 Q5
# Year                2023
# Engine_Size          2.0
# Fuel_Type       Electric
# Transmission      Manual
# Mileage           160971
# Doors                  2
# Owner_Count            1
# Price              11780
# Name: 3, dtype: object

# %%
df.iloc[2:4]
# Out:
#       Brand Model  Year  Engine_Size Fuel_Type Transmission  Mileage  Doors  \
# 2  Mercedes   GLA  2020          4.2    Diesel    Automatic   231440      4
# 3      Audi    Q5  2023          2.0  Electric       Manual   160971      2
#
#    Owner_Count  Price
# 2            2  11171
# 3            1  11780

# %%
df.iloc[2:4,4:7]
# Out:
#   Fuel_Type Transmission  Mileage
# 2    Diesel    Automatic   231440
# 3  Electric       Manual   160971

# %%
df.iloc[2:4,-1]
# Out:
# 2    11171
# 3    11780
# Name: Price, dtype: int64

# %%
df.iloc[:,2:4]
# Out:
#       Year  Engine_Size
# 0     2020          4.2
# 1     2012          2.0
# 2     2020          4.2
# 3     2023          2.0
# 4     2003          2.6
# ...    ...          ...
# 9995  2004          3.7
# 9996  2002          1.4
# 9997  2010          3.0
# 9998  2002          1.4
# 9999  2001          2.1
#
# [10000 rows x 2 columns]

# %%
df.head()
# Out:
#         Brand   Model  Year  Engine_Size Fuel_Type    Transmission  Mileage  \
# 0         Kia     Rio  2020          4.2    Diesel          Manual   289944
# 1   Chevrolet  Malibu  2012          2.0    Hybrid       Automatic     5356
# 2    Mercedes     GLA  2020          4.2    Diesel       Automatic   231440
# 3        Audi      Q5  2023          2.0  Electric          Manual   160971
# 4  Volkswagen    Golf  2003          2.6    Hybrid  Semi-Automatic   286618
#
#    Doors  Owner_Count  Price
# 0      3            5   8501
# 1      2            3  12092
# 2      4            2  11171
# 3      2            1  11780
# 4      3            3   2867

# %%
df.loc[4,:]
# Out:
# Brand               Volkswagen
# Model                     Golf
# Year                      2003
# Engine_Size                2.6
# Fuel_Type               Hybrid
# Transmission    Semi-Automatic
# Mileage                 286618
# Doors                        3
# Owner_Count                  3
# Price                     2867
# Name: 4, dtype: object

# %% [markdown]
# ## Statistics

# %%
# descriptive statistics, applicabe only for numeric fields
df.describe()
# Out:
#                Year   Engine_Size        Mileage         Doors   Owner_Count  \
# count  10000.000000  10000.000000   10000.000000  10000.000000  10000.000000
# mean    2011.543700      3.000560  149239.111800      3.497100      2.991100
# std        6.897699      1.149324   86322.348957      1.110097      1.422682
# min     2000.000000      1.000000      25.000000      2.000000      1.000000
# 25%     2006.000000      2.000000   74649.250000      3.000000      2.000000
# 50%     2012.000000      3.000000  149587.000000      3.000000      3.000000
# 75%     2017.000000      4.000000  223577.500000      4.000000      4.000000
# max     2023.000000      5.000000  299947.000000      5.000000      5.000000
#
#              Price
# count  10000.00000
# mean    8852.96440
# std     3112.59681
# min     2000.00000
# 25%     6646.00000
# 50%     8858.50000
# 75%    11086.50000
# max    18301.00000

# %%
# statistics for individual columns
print(df['Mileage'].mean()) # average
print(df['Mileage'].std()) # standard deviation
print(df['Mileage'].min())
print(df['Mileage'].quantile(0.25)) # also called Q1
print(df['Mileage'].median())       # also called Q2
print(df['Mileage'].quantile(0.75)) # also called Q3
print(df['Mileage'].max())
# Out:
# 149239.1118
# 86322.34895733811
# 25
# 74649.25
# 149587.0
# 223577.5
# 299947

# %% [markdown]
# ## Properties and shape

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Brand         10000 non-null  object
#  1   Model         10000 non-null  object
#  2   Year          10000 non-null  int64
#  3   Engine_Size   10000 non-null  float64
#  4   Fuel_Type     10000 non-null  object
#  5   Transmission  10000 non-null  object
#  6   Mileage       10000 non-null  int64
#  7   Doors         10000 non-null  int64
#  8   Owner_Count   10000 non-null  int64
#  9   Price         10000 non-null  int64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 781.4+ KB

# %%
df.shape # remember, this is a property not method, hence no brackets
# Out:
# (10000, 10)

# %% [markdown]
# ## Filtering

# %%
df_filtered = df[df['Brand'] == 'Audi']
df_filtered
# Out:
#      Brand Model  Year  Engine_Size Fuel_Type    Transmission  Mileage  Doors  \
# 3     Audi    Q5  2023          2.0  Electric          Manual   160971      2
# 26    Audi    A3  2022          3.3  Electric          Manual    79350      5
# 36    Audi    Q5  2013          3.5    Hybrid  Semi-Automatic   263411      4
# 39    Audi    A4  2004          1.0    Petrol          Manual    94415      2
# 44    Audi    Q5  2023          3.6  Electric          Manual   238306      5
# ...    ...   ...   ...          ...       ...             ...      ...    ...
# 9961  Audi    A4  2020          3.9    Petrol          Manual    91415      5
# 9968  Audi    A3  2006          2.5    Petrol  Semi-Automatic   155630      2
# 9985  Audi    A4  2003          1.4    Hybrid       Automatic   173657      4
# 9986  Audi    A4  2005          3.6    Petrol  Semi-Automatic   241546      4
# 9990  Audi    A3  2019          1.8  Electric          Manual    85496      4
#
#       Owner_Count  Price
# ...

# %%
df_filtered = df[(df['Brand'] == 'Audi') | (df['Brand'] == 'Mercedes')]
df_filtered
# Out:
#          Brand    Model  Year  Engine_Size Fuel_Type    Transmission  Mileage  \
# 2     Mercedes      GLA  2020          4.2    Diesel       Automatic   231440
# 3         Audi       Q5  2023          2.0  Electric          Manual   160971
# 19    Mercedes      GLA  2021          1.5    Petrol          Manual    34640
# 24    Mercedes      GLA  2016          3.9    Petrol  Semi-Automatic    19868
# 26        Audi       A3  2022          3.3  Electric          Manual    79350
# ...        ...      ...   ...          ...       ...             ...      ...
# 9983  Mercedes  E-Class  2022          3.2    Petrol       Automatic    92823
# 9985      Audi       A4  2003          1.4    Hybrid       Automatic   173657
# 9986      Audi       A4  2005          3.6    Petrol  Semi-Automatic   241546
# 9990      Audi       A3  2019          1.8  Electric          Manual    85496
# 9991  Mercedes  E-Class  2017          1.1    Diesel       Automatic   179286
#
#       Doors  Owner_Count  Price
# ...

# %%
df_filtered = df[df['Brand'].str.contains('Merc')]
df_filtered
# Out:
#          Brand    Model  Year  Engine_Size Fuel_Type    Transmission  Mileage  \
# 2     Mercedes      GLA  2020          4.2    Diesel       Automatic   231440
# 19    Mercedes      GLA  2021          1.5    Petrol          Manual    34640
# 24    Mercedes      GLA  2016          3.9    Petrol  Semi-Automatic    19868
# 33    Mercedes      GLA  2013          3.3  Electric  Semi-Automatic    80184
# 49    Mercedes      GLA  2013          1.9    Petrol          Manual   205005
# ...        ...      ...   ...          ...       ...             ...      ...
# 9974  Mercedes  C-Class  2020          1.1    Diesel          Manual    16669
# 9978  Mercedes  E-Class  2002          4.5    Diesel  Semi-Automatic   145363
# 9979  Mercedes  C-Class  2012          4.3    Diesel       Automatic    51674
# 9983  Mercedes  E-Class  2022          3.2    Petrol       Automatic    92823
# 9991  Mercedes  E-Class  2017          1.1    Diesel       Automatic   179286
#
#       Doors  Owner_Count  Price
# ...

# %%
df_filtered = df[df['Mileage'] > 290000]
df_filtered
# Out:
#            Brand     Model  Year  Engine_Size Fuel_Type    Transmission  \
# 10           BMW  5 Series  2013          1.3    Hybrid       Automatic
# 87          Ford     Focus  2013          1.1    Diesel          Manual
# 208       Toyota      RAV4  2008          3.5  Electric  Semi-Automatic
# 218       Toyota     Camry  2017          4.8  Electric  Semi-Automatic
# 232          BMW        X5  2002          2.9    Petrol          Manual
# ...          ...       ...   ...          ...       ...             ...
# 9775    Mercedes   C-Class  2011          4.2    Petrol  Semi-Automatic
# 9786         Kia  Sportage  2000          2.0    Petrol  Semi-Automatic
# 9847        Ford  Explorer  2022          2.5  Electric  Semi-Automatic
# 9851  Volkswagen    Passat  2000          2.2    Hybrid          Manual
# 9984  Volkswagen    Passat  2023          3.0    Hybrid          Manual
#
#       Mileage  Doors  Owner_Count  Price
# 10     296824      2            3   5863
# ...

# %%
df_filtered = df.query("Brand == 'Audi' & Doors > 4 & Mileage > 70000")
df_filtered
# Out:
#      Brand Model  Year  Engine_Size Fuel_Type    Transmission  Mileage  Doors  \
# 26    Audi    A3  2022          3.3  Electric          Manual    79350      5
# 44    Audi    Q5  2023          3.6  Electric          Manual   238306      5
# 48    Audi    A3  2009          1.2  Electric       Automatic   111448      5
# 93    Audi    Q5  2016          2.5  Electric  Semi-Automatic   121855      5
# 205   Audi    A3  2014          4.0    Petrol       Automatic   182364      5
# ...    ...   ...   ...          ...       ...             ...      ...    ...
# 9553  Audi    A3  2004          1.3  Electric  Semi-Automatic    76218      5
# 9554  Audi    A3  2021          2.8    Hybrid  Semi-Automatic    90107      5
# 9833  Audi    A4  2013          2.5    Petrol  Semi-Automatic    87407      5
# 9953  Audi    A4  2005          2.0    Petrol       Automatic   153520      5
# 9961  Audi    A4  2020          3.9    Petrol          Manual    91415      5
#
#       Owner_Count  Price
# ...

# %% [markdown]
# ## Data Cleaning

# %%
df

# %%
df.loc[9953:9999,['Brand','Doors']]= None
df.loc[2:3,['Fuel_Type']]= None
df.loc[4:8,['Transmission']]= None

df.isna().sum()
df.isnull().sum()
# Out:
# Brand           47
# Model            0
# Year             0
# Engine_Size      0
# Fuel_Type        2
# Transmission     5
# Mileage          0
# Doors           47
# Owner_Count      0
# Price            0
# dtype: int64

# %%
df.dropna()
# Out:
#            Brand     Model  Year  Engine_Size Fuel_Type    Transmission  \
# 0            Kia       Rio  2020          4.2    Diesel          Manual
# 1      Chevrolet    Malibu  2012          2.0    Hybrid       Automatic
# 9         Toyota      RAV4  2005          3.1    Petrol          Manual
# 10           BMW  5 Series  2013          1.3    Hybrid       Automatic
# 11    Volkswagen      Golf  2009          4.5    Hybrid          Manual
# ...          ...       ...   ...          ...       ...             ...
# 9948     Hyundai    Sonata  2013          1.7    Petrol          Manual
# 9949  Volkswagen      Golf  2017          4.9    Petrol       Automatic
# 9950   Chevrolet    Malibu  2020          2.4    Hybrid  Semi-Automatic
# 9951         BMW  3 Series  2020          3.4    Diesel       Automatic
# 9952    Mercedes       GLA  2015          4.9  Electric       Automatic
#
#       Mileage  Doors  Owner_Count  Price
# 0      289944    3.0            5   8501
# ...

# %%
df = reload_data()

# %%
df.dropna(subset=['Brand'])
# Out:
#            Brand     Model  Year  Engine_Size Fuel_Type    Transmission  \
# 0            Kia       Rio  2020          4.2    Diesel          Manual
# 1      Chevrolet    Malibu  2012          2.0    Hybrid       Automatic
# 2       Mercedes       GLA  2020          4.2      None       Automatic
# 3           Audi        Q5  2023          2.0      None          Manual
# 4     Volkswagen      Golf  2003          2.6    Hybrid            None
# ...          ...       ...   ...          ...       ...             ...
# 9948     Hyundai    Sonata  2013          1.7    Petrol          Manual
# 9949  Volkswagen      Golf  2017          4.9    Petrol       Automatic
# 9950   Chevrolet    Malibu  2020          2.4    Hybrid  Semi-Automatic
# 9951         BMW  3 Series  2020          3.4    Diesel       Automatic
# 9952    Mercedes       GLA  2015          4.9  Electric       Automatic
#
#       Mileage  Doors  Owner_Count  Price
# 0      289944    3.0            5   8501
# ...

# %%
df.fillna('Unknown')
# Out:
#            Brand     Model  Year  Engine_Size Fuel_Type    Transmission  \
# 0            Kia       Rio  2020          4.2    Diesel          Manual
# 1      Chevrolet    Malibu  2012          2.0    Hybrid       Automatic
# 2       Mercedes       GLA  2020          4.2   Unknown       Automatic
# 3           Audi        Q5  2023          2.0   Unknown          Manual
# 4     Volkswagen      Golf  2003          2.6    Hybrid         Unknown
# ...          ...       ...   ...          ...       ...             ...
# 9995     Unknown    Optima  2004          3.7    Diesel  Semi-Automatic
# 9996     Unknown    Impala  2002          1.4  Electric       Automatic
# 9997     Unknown  3 Series  2010          3.0    Petrol       Automatic
# 9998     Unknown  Explorer  2002          1.4    Hybrid       Automatic
# 9999     Unknown    Tiguan  2001          2.1    Diesel          Manual
#
#       Mileage    Doors  Owner_Count  Price
# 0      289944      3.0            5   8501
# ...

# %%
df[df.duplicated]
# Out:
# Empty DataFrame
# Columns: [Brand, Model, Year, Engine_Size, Fuel_Type, Transmission, Mileage, Doors, Owner_Count, Price]
# Index: []

# %%
df.drop_duplicates()

# %%
df['Brand'].value_counts()
# Out:
# Brand
# Ford          1045
# Audi          1031
# Volkswagen    1015
# Honda         1006
# Chevrolet      998
# Hyundai        994
# BMW            990
# Kia            973
# Toyota         966
# Mercedes       935
# Name: count, dtype: int64

# %%
df['Fuel_Type'].unique()
# Out:
# array(['Diesel', 'Hybrid', None, 'Petrol', 'Electric'], dtype=object)

# %% [markdown]
# ## Column Manipulation

# %%
df.drop('Price',axis=1)
# Out:
#            Brand     Model  Year  Engine_Size Fuel_Type    Transmission  \
# 0            Kia       Rio  2020          4.2    Diesel          Manual
# 1      Chevrolet    Malibu  2012          2.0    Hybrid       Automatic
# 2       Mercedes       GLA  2020          4.2      None       Automatic
# 3           Audi        Q5  2023          2.0      None          Manual
# 4     Volkswagen      Golf  2003          2.6    Hybrid            None
# ...          ...       ...   ...          ...       ...             ...
# 9995        None    Optima  2004          3.7    Diesel  Semi-Automatic
# 9996        None    Impala  2002          1.4  Electric       Automatic
# 9997        None  3 Series  2010          3.0    Petrol       Automatic
# 9998        None  Explorer  2002          1.4    Hybrid       Automatic
# 9999        None    Tiguan  2001          2.1    Diesel          Manual
#
#       Mileage  Doors  Owner_Count
# 0      289944    3.0            5
# ...

# %%
df = df.rename(columns={'Fuel_Type':'IsEV'})
df
# Out:
#            Brand     Model  Year  Engine_Size      IsEV    Transmission  \
# 0            Kia       Rio  2020          4.2    Diesel          Manual
# 1      Chevrolet    Malibu  2012          2.0    Hybrid       Automatic
# 2       Mercedes       GLA  2020          4.2      None       Automatic
# 3           Audi        Q5  2023          2.0      None          Manual
# 4     Volkswagen      Golf  2003          2.6    Hybrid            None
# ...          ...       ...   ...          ...       ...             ...
# 9995        None    Optima  2004          3.7    Diesel  Semi-Automatic
# 9996        None    Impala  2002          1.4  Electric       Automatic
# 9997        None  3 Series  2010          3.0    Petrol       Automatic
# 9998        None  Explorer  2002          1.4    Hybrid       Automatic
# 9999        None    Tiguan  2001          2.1    Diesel          Manual
#
#       Mileage  Doors  Owner_Count  Price
# 0      289944    3.0            5   8501
# ...

# %%
df['NewColumn'] = df['Brand']
df
# Out:
#            Brand     Model  Year  Engine_Size      IsEV    Transmission  \
# 0            Kia       Rio  2020          4.2    Diesel          Manual
# 1      Chevrolet    Malibu  2012          2.0    Hybrid       Automatic
# 2       Mercedes       GLA  2020          4.2      None       Automatic
# 3           Audi        Q5  2023          2.0      None          Manual
# 4     Volkswagen      Golf  2003          2.6    Hybrid            None
# ...          ...       ...   ...          ...       ...             ...
# 9995        None    Optima  2004          3.7    Diesel  Semi-Automatic
# 9996        None    Impala  2002          1.4  Electric       Automatic
# 9997        None  3 Series  2010          3.0    Petrol       Automatic
# 9998        None  Explorer  2002          1.4    Hybrid       Automatic
# 9999        None    Tiguan  2001          2.1    Diesel          Manual
#
#       Mileage  Doors  Owner_Count  Price   NewColumn
# ...

# %%
df['CarAge'] = 2025 - df['Year']
df
# Out:
#            Brand     Model  Year  Engine_Size      IsEV    Transmission  \
# 0            Kia       Rio  2020          4.2    Diesel          Manual
# 1      Chevrolet    Malibu  2012          2.0    Hybrid       Automatic
# 2       Mercedes       GLA  2020          4.2      None       Automatic
# 3           Audi        Q5  2023          2.0      None          Manual
# 4     Volkswagen      Golf  2003          2.6    Hybrid            None
# ...          ...       ...   ...          ...       ...             ...
# 9995        None    Optima  2004          3.7    Diesel  Semi-Automatic
# 9996        None    Impala  2002          1.4  Electric       Automatic
# 9997        None  3 Series  2010          3.0    Petrol       Automatic
# 9998        None  Explorer  2002          1.4    Hybrid       Automatic
# 9999        None    Tiguan  2001          2.1    Diesel          Manual
#
#       Mileage  Doors  Owner_Count  Price   NewColumn  CarAge
# ...

# %%
df['IsEV'] = df['IsEV'].apply(lambda x: 1 if x == 'Electric' else 0)
df
# Out:
#            Brand     Model  Year  Engine_Size  IsEV    Transmission  Mileage  \
# 0            Kia       Rio  2020          4.2     0          Manual   289944
# 1      Chevrolet    Malibu  2012          2.0     0       Automatic     5356
# 2       Mercedes       GLA  2020          4.2     0       Automatic   231440
# 3           Audi        Q5  2023          2.0     0          Manual   160971
# 4     Volkswagen      Golf  2003          2.6     0            None   286618
# ...          ...       ...   ...          ...   ...             ...      ...
# 9995        None    Optima  2004          3.7     0  Semi-Automatic     5794
# 9996        None    Impala  2002          1.4     1       Automatic   168000
# 9997        None  3 Series  2010          3.0     0       Automatic    86664
# 9998        None  Explorer  2002          1.4     0       Automatic   225772
# 9999        None    Tiguan  2001          2.1     0          Manual   157882
#
# ...

# %% [markdown]
# ## Datatypes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Brand         9953 non-null   object
#  1   Model         10000 non-null  object
#  2   Year          10000 non-null  int64
#  3   Engine_Size   10000 non-null  float64
#  4   IsEV          10000 non-null  int64
#  5   Transmission  9995 non-null   object
#  6   Mileage       10000 non-null  int64
#  7   Doors         9953 non-null   float64
#  8   Owner_Count   10000 non-null  int64
#  9   Price         10000 non-null  int64
#  10  NewColumn     9953 non-null   object
#  11  CarAge        10000 non-null  int64
# dtypes: float64(2), int64(6), object(4)
# memory usage: 937.6+ KB

# %%
df['Brand'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 10000 entries, 0 to 9999
# Series name: Brand
# Non-Null Count  Dtype
# --------------  -----
# 9953 non-null   object
# dtypes: object(1)
# memory usage: 78.3+ KB

# %% [markdown]
# ## Indexing

# %%
df_index = df.set_index('Brand')
df_index
# Out:
#                Model  Year  Engine_Size  IsEV    Transmission  Mileage  Doors  \
# Brand
# Kia              Rio  2020          4.2     0          Manual   289944    3.0
# Chevrolet     Malibu  2012          2.0     0       Automatic     5356    2.0
# Mercedes         GLA  2020          4.2     0       Automatic   231440    4.0
# Audi              Q5  2023          2.0     0          Manual   160971    2.0
# Volkswagen      Golf  2003          2.6     0            None   286618    3.0
# ...              ...   ...          ...   ...             ...      ...    ...
# None          Optima  2004          3.7     0  Semi-Automatic     5794    NaN
# None          Impala  2002          1.4     1       Automatic   168000    NaN
# None        3 Series  2010          3.0     0       Automatic    86664    NaN
# None        Explorer  2002          1.4     0       Automatic   225772    NaN
# None          Tiguan  2001          2.1     0          Manual   157882    NaN
#
# ...

# %%
df_index.loc['Kia']
# Out:
#           Model  Year  Engine_Size  IsEV    Transmission  Mileage  Doors  \
# Brand
# Kia         Rio  2020          4.2     0          Manual   289944    3.0
# Kia    Sportage  2001          4.7     1            None   157495    2.0
# Kia    Sportage  2014          2.6     0            None    98700    3.0
# Kia         Rio  2000          3.4     0  Semi-Automatic   257427    3.0
# Kia    Sportage  2011          1.8     0       Automatic    92188    2.0
# ...         ...   ...          ...   ...             ...      ...    ...
# Kia    Sportage  2004          3.3     0  Semi-Automatic   285789    5.0
# Kia      Optima  2014          4.6     0  Semi-Automatic   193673    2.0
# Kia         Rio  2001          3.3     0  Semi-Automatic   262793    4.0
# Kia      Optima  2002          1.4     0       Automatic   160394    3.0
# Kia         Rio  2000          3.4     0          Manual   173249    5.0
#
#        Owner_Count  Price NewColumn  CarAge
# Brand
# ...

# %%
df_index.sort_index()
# Out:
#           Model  Year  Engine_Size  IsEV    Transmission  Mileage  Doors  \
# Brand
# Audi         A4  2015          1.1     0  Semi-Automatic   128408    2.0
# Audi         Q5  2010          3.1     1       Automatic   180328    4.0
# Audi         A3  2018          1.1     0  Semi-Automatic    12539    3.0
# Audi         Q5  2016          3.8     0          Manual    69756    3.0
# Audi         Q5  2018          3.7     0       Automatic   140877    5.0
# ...         ...   ...          ...   ...             ...      ...    ...
# None     Optima  2004          3.7     0  Semi-Automatic     5794    NaN
# None     Impala  2002          1.4     1       Automatic   168000    NaN
# None   3 Series  2010          3.0     0       Automatic    86664    NaN
# None   Explorer  2002          1.4     0       Automatic   225772    NaN
# None     Tiguan  2001          2.1     0          Manual   157882    NaN
#
#        Owner_Count  Price NewColumn  CarAge
# Brand
# ...

# %%
df_index.sort_index(ascending=False)
# Out:
#                Model  Year  Engine_Size  IsEV    Transmission  Mileage  Doors  \
# Brand
# Volkswagen      Golf  2001          4.4     1  Semi-Automatic    69825    2.0
# Volkswagen    Tiguan  2018          2.1     1       Automatic   182259    3.0
# Volkswagen    Passat  2007          3.0     1          Manual   272439    3.0
# Volkswagen    Tiguan  2005          4.9     1          Manual   195620    3.0
# Volkswagen      Golf  2011          2.9     0  Semi-Automatic   106916    2.0
# ...              ...   ...          ...   ...             ...      ...    ...
# None          Optima  2004          3.7     0  Semi-Automatic     5794    NaN
# None          Impala  2002          1.4     1       Automatic   168000    NaN
# None        3 Series  2010          3.0     0       Automatic    86664    NaN
# None        Explorer  2002          1.4     0       Automatic   225772    NaN
# None          Tiguan  2001          2.1     0          Manual   157882    NaN
#
# ...

# %%
df_index.reset_index()
# Out:
#            Brand     Model  Year  Engine_Size  IsEV    Transmission  Mileage  \
# 0            Kia       Rio  2020          4.2     0          Manual   289944
# 1      Chevrolet    Malibu  2012          2.0     0       Automatic     5356
# 2       Mercedes       GLA  2020          4.2     0       Automatic   231440
# 3           Audi        Q5  2023          2.0     0          Manual   160971
# 4     Volkswagen      Golf  2003          2.6     0            None   286618
# ...          ...       ...   ...          ...   ...             ...      ...
# 9995        None    Optima  2004          3.7     0  Semi-Automatic     5794
# 9996        None    Impala  2002          1.4     1       Automatic   168000
# 9997        None  3 Series  2010          3.0     0       Automatic    86664
# 9998        None  Explorer  2002          1.4     0       Automatic   225772
# 9999        None    Tiguan  2001          2.1     0          Manual   157882
#
# ...

# %% [markdown]
# ## Sorting and Grouping

# %%
df.sort_values('Brand')
# Out:
#      Brand     Model  Year  Engine_Size  IsEV    Transmission  Mileage  Doors  \
# 4729  Audi        A4  2015          1.1     0  Semi-Automatic   128408    2.0
# 869   Audi        Q5  2010          3.1     1       Automatic   180328    4.0
# 7635  Audi        A3  2018          1.1     0  Semi-Automatic    12539    3.0
# 2664  Audi        Q5  2016          3.8     0          Manual    69756    3.0
# 4429  Audi        Q5  2018          3.7     0       Automatic   140877    5.0
# ...    ...       ...   ...          ...   ...             ...      ...    ...
# 9995  None    Optima  2004          3.7     0  Semi-Automatic     5794    NaN
# 9996  None    Impala  2002          1.4     1       Automatic   168000    NaN
# 9997  None  3 Series  2010          3.0     0       Automatic    86664    NaN
# 9998  None  Explorer  2002          1.4     0       Automatic   225772    NaN
# 9999  None    Tiguan  2001          2.1     0          Manual   157882    NaN
#
# ...

# %%
df.sort_values('Brand',ascending=False)
# Out:
#            Brand     Model  Year  Engine_Size  IsEV    Transmission  Mileage  \
# 5282  Volkswagen      Golf  2001          4.4     1  Semi-Automatic    69825
# 3913  Volkswagen    Tiguan  2018          2.1     1       Automatic   182259
# 697   Volkswagen    Passat  2007          3.0     1          Manual   272439
# 3113  Volkswagen    Tiguan  2005          4.9     1          Manual   195620
# 7905  Volkswagen      Golf  2011          2.9     0  Semi-Automatic   106916
# ...          ...       ...   ...          ...   ...             ...      ...
# 9995        None    Optima  2004          3.7     0  Semi-Automatic     5794
# 9996        None    Impala  2002          1.4     1       Automatic   168000
# 9997        None  3 Series  2010          3.0     0       Automatic    86664
# 9998        None  Explorer  2002          1.4     0       Automatic   225772
# 9999        None    Tiguan  2001          2.1     0          Manual   157882
#
# ...

# %%
df_grouped = df.groupby(['Brand','Model','Transmission'])['Mileage'].mean()
df_grouped
# Out:
# Brand       Model   Transmission
# Audi        A3      Automatic         159126.589744
#                     Manual            141350.350000
#                     Semi-Automatic    153061.621849
#             A4      Automatic         146473.614679
#                     Manual            157300.480000
#                                           ...
# Volkswagen  Passat  Manual            146828.509259
#                     Semi-Automatic    154514.917431
#             Tiguan  Automatic         150566.769231
#                     Manual            146257.735537
#                     Semi-Automatic    144611.282828
# Name: Mileage, Length: 90, dtype: float64

# %% [markdown]
# ## Graphs

# %%
df['Brand'].value_counts()
# Out:
# Brand
# Ford          1045
# Audi          1031
# Volkswagen    1015
# Honda         1006
# Chevrolet      998
# Hyundai        994
# BMW            990
# Kia            973
# Toyota         966
# Mercedes       935
# Name: count, dtype: int64

# %%
df['Brand'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Brand'>

# %%
df['Brand'].value_counts().plot.pie()
# Out:
# <Axes: ylabel='count'>
